# %%
#Create a JSON file (employee.json) containing employee information of minimum 5 employees.
#Each employee information consists of Name, DOB, Height, City, State.
#Write a python program that reads this information from the JSON file and saves the information into a list of objects of Employee class.
#Finally print the list of the Employee objects.
import json

data_JSON =  """
{
   "employee.json": [

      {
         "name": "MUSKAN SINGH",
         "dob": "24.06.01",
         "height": "5.4",
         "city": "patna",
         "state": "bihar"
      },

      {
         "name": "DEEPANSH SINGH",
         "dob": "21.08.01",
         "height": "5.10",
         "city": "Varanasi",
         "state": "UP"
      },
      {
         "name": "ADTIYA",
         "dob": "24.06.01",
         "height": "5.6",
         "city": "patna",
         "state": "bihar"
       },
       {
         "name": "Rahul sonal razz",
         "dob": "24.06.01",
         "height": "5.4",
         "city": "patna",
         "state": "bihar"
       },
       {
         "name": "Nisita Karn",
         "dob": "24.06.01",
         "height": "5.4",
         "city": "patna",
         "state": "bihar"
       }
   ]
}
"""

data_dict = json.loads(data_JSON)
print(data_dict["employee.json"])
# Out:
# [{'name': 'MUSKAN SINGH', 'dob': '24.06.01', 'height': '5.4', 'city': 'patna', 'state': 'bihar'}, {'name': 'DEEPANSH SINGH', 'dob': '21.08.01', 'height': '5.10', 'city': 'Varanasi', 'state': 'UP'}, {'name': 'ADTIYA', 'dob': '24.06.01', 'height': '5.6', 'city': 'patna', 'state': 'bihar'}, {'name': 'Rahul sonal razz', 'dob': '24.06.01', 'height': '5.4', 'city': 'patna', 'state': 'bihar'}, {'name': 'Nisita Karn', 'dob': '24.06.01', 'height': '5.4', 'city': 'patna', 'state': 'bihar'}]

# %%
#Dictionary of 7 Indian states and their captials
import json
state_capital ={'Bihar':'Patna',
                'Goa':'Panji',
                'sikkim':'Gangtok',
                'west Bengal':'Kolkata',
                'Haryana':'Chandigarh',
                'Assam':'Dispur',
                'Madhya Pradesh':'Bhopal'
                    }

json_string = json.dumps(state_capital)
print(json_string)
# Out:
# {"Bihar": "Patna", "Goa": "Panji", "sikkim": "Gangtok", "west Bengal": "Kolkata", "Haryana": "Chandigarh", "Assam": "Dispur", "Madhya Pradesh": "Bhopal"}

# %%
# 1. Create a class named ‘Dog’. It should have a constructor which accepts its name, age and coat color. 
# You must perform the following operations:

# 🔴 a. It should have a function ‘description()’ which prints the name and age of the dog.
# 🔴 b. It should have a function ‘get_info()’ which prints the coat color of the dog.
# 🔴 c. Create child classes ‘JackRussellTerrier’ and ‘Bulldog’ which is inherited from the class ‘Dog’. 
# It should have at least two methods of its own.
# 🔴 d. Create objects and implement the above functionalities.

class Dog:
    def __init__(self,name, age, coat_color):
        self.name=name
        self.age=age
        self.coat_color=coat_color
    def description(self):
        print(f"name of the Dog is {self.name}")
        print(f"age of the dog is {self.age}")
        
    def get_info(self):
        print(f'coat color of the dog is {self.coat_color}')
        
class JackRussellTerrier(Dog):
    def __init__(self,name, age, coat_color,hieght="25-38 cm",mass="6-8 kg",bodylength="46-55cm"):
        super().__init__(name, age, coat_color)
        self.hieght=hieght
        self.mass=mass
        self.bodylength=bodylength
    def lifespan(self,lifeline="Lifespan of this dog breed is 12-16 years"):
        print(lifeline)
        
    def temprament(self):
        temper="Temprament of this dog breed is Intelligent, Stubbon, Athletic, Energetic, Fearless"
        print(temper)
        
    def getappearance(self):
        print(f"height of Jack Russell Terrier is {self.hieght}")
        print(f"weight of Jack Russell Terrier is {self.mass}")
        print(f"overall bodylength of Jack Russell  Terrier is {self.bodylength}")
         

class Bulldog(Dog):
    def __init__(self,name, age, coat_color,hieght="31-40 cm",mass="23-25 kg",bodylength="51-69 cm"):
        super().__init__(name, age, coat_color)
        self.hieght=hieght
        self.mass=mass
        self.bodylength=bodylength
        
    def lifespan(self):
        lifeline="Lifespan of this dog breed is 8-10 years"
        print(lifeline)
        
    def temprament(self):
        temper="Temprament of this dog breed is Docile, Friendly, Gregacious"
        print(temper)
        
    def getappearance(self):
        print(f"height of Bulldog is {self.hieght}")
        print(f"weight of Bulldog is {self.mass}")
        print(f"overall bodylength of Bulldog is {self.bodylength}")
        

J=JackRussellTerrier("Jackson",5,"White")
J.description()
J.get_info()
J.getappearance()
J.temprament()

B=Bulldog("Heather", 7, "Brindle & White")
B.description()
B.get_info()
B.getappearance()
B.temprament()
# Out:
# name of the Dog is Jackson
# age of the dog is 5
# coat color of the dog is White
# height of Jack Russell Terrier is 25-38 cm
# weight of Jack Russell Terrier is 6-8 kg
# overall bodylength of Jack Russell  Terrier is 46-55cm
# Temprament of this dog breed is Intelligent, Stubbon, Athletic, Energetic, Fearless
# name of the Dog is Heather
# age of the dog is 7
# coat color of the dog is Brindle & White
# height of Bulldog is 31-40 cm
# weight of Bulldog is 23-25 kg
# overall bodylength of Bulldog is 51-69 cm
# Temprament of this dog breed is Docile, Friendly, Gregacious
